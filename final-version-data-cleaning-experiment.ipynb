# %% [markdown]
# <a href="https://www.kaggle.com/code/arianrahman/data-cleaning-experiment?scriptVersionId=104741592" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/homes-dataset/Homes.csv

# %%
import  numpy as np 
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_csv("/kaggle/input/homes-dataset/Homes.csv")

# %%
df.head(39).T
# Out:
#                          0                   1                   2   \
# address       1866 20th Ave        1639 Pine St  6 Ac County Road Z
# price              $294,900             $89,500            $199,900
# beds                  1 Bed              2 Beds             6 Acres
# bath                 1 Bath              1 Bath                 NaN
# size            964 Sq. Ft.         924 Sq. Ft.                 NaN
# place    Arkdale, WI, 54613  Arkdale, WI, 54613  Arkdale, WI, 54613
#
#                            3                   4                    5   \
# address  1827 E County Road Z       1644 20th Ave  2054 Cumberland Ave
# price                 $98,900            $475,000             $179,000
# beds                  9 Acres              3 Beds               4 Beds
# bath                      NaN             2 Baths               1 Bath
# size                      NaN       2,184 Sq. Ft.        1,744 Sq. Ft.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   address  1700 non-null   object
#  1   price    1700 non-null   object
#  2   beds     1695 non-null   object
#  3   bath     1495 non-null   object
#  4   size     1363 non-null   object
#  5   place    1700 non-null   object
# dtypes: object(6)
# memory usage: 79.8+ KB

# %%
df["bath"].head(20)
# Out:
# 0      1 Bath
# 1      1 Bath
# 2         NaN
# 3         NaN
# 4     2 Baths
# 5      1 Bath
# 6     2 Baths
# 7     2 Baths
# 8     2 Baths
# 9      1 Bath
# 10        NaN
# 11        NaN
# 12        NaN
# 13     1 Bath
# 14    2 Baths
# 15    2 Baths
# 16        NaN
# 17    2 Baths
# 18    2 Baths
# 19        NaN
# Name: bath, dtype: object

# %%
# new data frame with split value columns
new = df["bath"].str.split(" ", n = 1, expand = True)
 
# making separate first name column from new data frame
df["bath"]= new[0]

new = df['beds'].str.split(" ",n = 1, expand = True )

df['beds']=new[0]
    
new = df['size'].str.split(" ",n = 1, expand = True )

df['size_sq.ft']=new[0]

# %%
df.tail(39).T
# Out:
#                              1661               1662               1663  \
# address     38 Southern Boulevard  284 Morton Avenue     79 Morris Road
# price                    $129,900           $160,000            $45,900
# beds                            3                  6               0.48
# bath                            1              2,444                NaN
# size                1,132 Sq. Ft.                NaN                NaN
# place           Albany, NY, 12209  Albany, NY, 12209  Albany, NY, 12304
# size_sq.ft                  1,132                NaN                NaN
#
#                          1664               1665               1666  \
# address          119 Chestnut     81 Morris Road  326A Consaul Road
# price                $287,000            $49,900            $25,000
# beds                        4               0.48               0.74
# bath                        3                NaN                NaN
# ...

# %%
df['price'] =  df['price'].str.strip("$")

# %%
df['price'].head(10)
# Out:
# 0    294,900
# 1     89,500
# 2    199,900
# 3     98,900
# 4    475,000
# 5    179,000
# 6    359,000
# 7    359,900
# 8    359,000
# 9    139,900
# Name: price, dtype: object

# %%
df['size_sq.ft'] =  df['size_sq.ft'].str.strip(",")



df.head(10)
# Out:
#                         address    price beds bath           size  \
# 0                 1866 20th Ave  294,900    1    1    964 Sq. Ft.
# 1                  1639 Pine St   89,500    2    1    924 Sq. Ft.
# 2            6 Ac County Road Z  199,900    6  NaN            NaN
# 3          1827 E County Road Z   98,900    9  NaN            NaN
# 4                 1644 20th Ave  475,000    3    2  2,184 Sq. Ft.
# 5           2054 Cumberland Ave  179,000    4    1  1,744 Sq. Ft.
# 6                  1841 20th Ct  359,000    3    2  1,689 Sq. Ft.
# 7  2011-4 S Czech Crossing 3004  359,900    4    2  2,238 Sq. Ft.
# 8        2009-7 S Czech Ct 0907  359,000    3    2  2,132 Sq. Ft.
# 9            1988 Cumberland Dr  139,900    1    1    580 Sq. Ft.
#
#                 place size_sq.ft
# 0  Arkdale, WI, 54613        964
# 1  Arkdale, WI, 54613        924
# 2  Arkdale, WI, 54613        NaN
# 3  Arkdale, WI, 54613        NaN
# 4  Arkdale, WI, 54613      2,184
# 5  Arkdale, WI, 54613      1,744
# ...

# %% [markdown]
# **PROBLEM  : Here the comma is supposed to be removed but isn't**

# %%
# str.strp didn't work as it only works for removing characters in the front or back  

df['size_sq.ft']=df['size_sq.ft'].str.replace("," , "")   

#.str.replace(",", "")

df['size_sq.ft'].head(20)
# Out:
# 0      964
# 1      924
# 2      NaN
# 3      NaN
# 4     2184
# 5     1744
# 6     1689
# 7     2238
# 8     2132
# 9      580
# 10     NaN
# 11     NaN
# 12     NaN
# 13     960
# 14    2000
# 15    2132
# 16     NaN
# 17    1026
# 18    1344
# 19     NaN
# Name: size_sq.ft, dtype: object

# %%
# removing comma from price 

df['price']=df['price'].str.replace("," , "")   


df['price'].head(20)
# Out:
# 0     294900
# 1      89500
# 2     199900
# 3      98900
# 4     475000
# 5     179000
# 6     359000
# 7     359900
# 8     359000
# 9     139900
# 10    119900
# 11     29900
# 12    109900
# 13    165000
# 14    330000
# 15    350000
# 16     95000
# 17    159000
# 18     85000
# 19     35900
# Name: price, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   address     1700 non-null   object
#  1   price       1700 non-null   object
#  2   beds        1695 non-null   object
#  3   bath        1495 non-null   object
#  4   size        1363 non-null   object
#  5   place       1700 non-null   object
#  6   size_sq.ft  1363 non-null   object
# dtypes: object(7)
# memory usage: 93.1+ KB

# %%
# now the cols are ready to be converted into Numeric data

df['beds'] = pd.to_numeric(df['beds'], errors='coerce')
df['bath'] = pd.to_numeric(df['bath'], errors='coerce')
df['size_sq.ft'] = pd.to_numeric(df['size_sq.ft'], errors='coerce')
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
df.drop('size', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   address     1700 non-null   object
#  1   price       1700 non-null   int64
#  2   beds        1651 non-null   float64
#  3   bath        1370 non-null   float64
#  4   place       1700 non-null   object
#  5   size_sq.ft  1363 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 79.8+ KB

# %%
df.head(49)
# Out:
#                             address    price   beds  bath               place  \
# 0                     1866 20th Ave   294900   1.00   1.0  Arkdale, WI, 54613
# 1                      1639 Pine St    89500   2.00   1.0  Arkdale, WI, 54613
# 2                6 Ac County Road Z   199900   6.00   NaN  Arkdale, WI, 54613
# 3              1827 E County Road Z    98900   9.00   NaN  Arkdale, WI, 54613
# 4                     1644 20th Ave   475000   3.00   2.0  Arkdale, WI, 54613
# 5               2054 Cumberland Ave   179000   4.00   1.0  Arkdale, WI, 54613
# 6                      1841 20th Ct   359000   3.00   2.0  Arkdale, WI, 54613
# 7      2011-4 S Czech Crossing 3004   359900   4.00   2.0  Arkdale, WI, 54613
# 8            2009-7 S Czech Ct 0907   359000   3.00   2.0  Arkdale, WI, 54613
# 9                1988 Cumberland Dr   139900   1.00   1.0  Arkdale, WI, 54613
# 10                 Lot 25 19th Pass   119900   1.00   NaN  Arkdale, WI, 54613
# ...

# %%
import missingno as mno

mno.matrix(df, figsize = (20, 6),labels=True)
# Out:
# <AxesSubplot:>

# %%
df.count()
# Out:
# address       1700
# price         1700
# beds          1651
# bath          1370
# place         1700
# size_sq.ft    1363
# dtype: int64

# %%
# # This is random impuration , it does not concern with relationship with other columns when filling missing values. 

# missing_columns = ["beds","bath","size_sq.ft"]


# def random_imputation(df, feature):

#     number_missing = df[feature].isnull().sum()
#     observed_values = df.loc[df[feature].notnull(), feature]
#     df.loc[df[feature].isnull(), feature + '_imp'] = np.random.choice(observed_values, number_missing, replace = True)
    
#     return df



# for feature in missing_columns:
#     df[feature + '_imp'] = df[feature]
#     df = random_imputation(df, feature)


# df.info()

# %%
df.head(46)
# Out:
#                             address    price   beds  bath               place  \
# 0                     1866 20th Ave   294900   1.00   1.0  Arkdale, WI, 54613
# 1                      1639 Pine St    89500   2.00   1.0  Arkdale, WI, 54613
# 2                6 Ac County Road Z   199900   6.00   NaN  Arkdale, WI, 54613
# 3              1827 E County Road Z    98900   9.00   NaN  Arkdale, WI, 54613
# 4                     1644 20th Ave   475000   3.00   2.0  Arkdale, WI, 54613
# 5               2054 Cumberland Ave   179000   4.00   1.0  Arkdale, WI, 54613
# 6                      1841 20th Ct   359000   3.00   2.0  Arkdale, WI, 54613
# 7      2011-4 S Czech Crossing 3004   359900   4.00   2.0  Arkdale, WI, 54613
# 8            2009-7 S Czech Ct 0907   359000   3.00   2.0  Arkdale, WI, 54613
# 9                1988 Cumberland Dr   139900   1.00   1.0  Arkdale, WI, 54613
# 10                 Lot 25 19th Pass   119900   1.00   NaN  Arkdale, WI, 54613
# ...

# %%
df.dropna()
# Out:
#                          address   price  beds  bath               place  \
# 0                  1866 20th Ave  294900   1.0   1.0  Arkdale, WI, 54613
# 1                   1639 Pine St   89500   2.0   1.0  Arkdale, WI, 54613
# 4                  1644 20th Ave  475000   3.0   2.0  Arkdale, WI, 54613
# 5            2054 Cumberland Ave  179000   4.0   1.0  Arkdale, WI, 54613
# 6                   1841 20th Ct  359000   3.0   2.0  Arkdale, WI, 54613
# ...                          ...     ...   ...   ...                 ...
# 1694           23 Twiller Street  179900   3.0   1.0   Albany, NY, 12209
# 1695  1025 Washington Ave Avenue  279900   3.0   2.0   Albany, NY, 12206
# 1697            49 Albany Street  149900   3.0   2.0   Albany, NY, 12204
# 1698         36 Woodridge Street  229000   3.0   1.0   Albany, NY, 12203
# 1699         25B Pine Lane Apt 2  150000   2.0   1.0   Albany, NY, 12203
#
#       size_sq.ft
# 0          964.0
# 1          924.0
# 4         2184.0
# 5         1744.0
# ...

# %%
df.rename(columns={'price':'price_$'},inplace=True)

# %%
#df.to_csv(index=False)

df.to_csv('cleaned_house_data.csv',index= False)

# %% [markdown]
# ### To download the clean csv file format, expand the Output foler on the right and click on the csv file.
